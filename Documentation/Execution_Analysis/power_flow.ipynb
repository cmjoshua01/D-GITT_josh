# %% [markdown]
# # Running a powerflow given injection data

# %% [markdown]
# This notebook will outline how to run powerflow algorithms given a grid and injection snapshot. The example in this notebook includes an incomplete dataset, and some synthetic data and powerflow tuning are utilized to run a convergent powerflow. The specifics of the approach taken here are motivated, but not optimal! We encourage the reader to try their own ideas.

# %%
import pypowsybl as pp
import pandas as pd
from pathlib import Path
import numpy as np

grid = pp.network.load(file='recollement-auto-20210101-0000-enrichi.xiidm.bz2')
print('Grid model loaded')

grid.get_generators()

grid1= grid
# Out:
# Grid model loaded

# %% [markdown]
# This notebook uses injections that are in the .parquet format, for which we can use the pyarrow engine to read and convert them to a pandas dataframe. We can compare the below injected generator snapshot to the grid generator data above, noticing that much of the information is simply repeated, but that the critical values for `target_p` (the generator´s real power output) are included in the injection. These are necessary for us to be able to run a power flow.

# %%
#These snapshots are separated by element type, so we create a pandas dataframe for each of those we are interested in: the generators, loads and buses

df_inj_gen = pd.read_parquet("snapshot_gen_2021-01-01T00-00-00.parquet", engine="pyarrow")
df_inj_load = pd.read_parquet("snapshot_load_2021-01-01T00-00-00.parquet", engine="pyarrow")
df_inj_bus = pd.read_parquet("snapshot_bus_2021-01-01T00-00-00.parquet", engine="pyarrow")

#We can look into one of these snapshots to see what it contains
df_inj_gen
# Out:
#        datetime             id name energy_source  target_p  min_p  max_p  \
# 0    2021-01-01  .CTLO3GROUP.1  NaN         hydro     0.150    0.0  0.150
# 1    2021-01-01  .CTLO3GROUP.2  NaN         hydro     0.150    0.0  0.150
# 2    2021-01-01       ARGIAINF  NaN         solar     0.000    0.0  0.007
# 3    2021-01-01       ARGOEIN2  NaN          wind     0.000    0.0  0.000
# 4    2021-01-01       ARGOEIN3  NaN          wind     0.144    0.0  0.144
# ...         ...            ...  ...           ...       ...    ...    ...
# 5620 2021-01-01       YQUELING  NaN         solar     0.000    0.0  0.023
# 5621 2021-01-01       YVETOINF  NaN         solar     0.000    0.0  0.004
# 5622 2021-01-01       YVETOING  NaN         solar     0.000    0.0  0.004
# 5623 2021-01-01       YZEURIN2  NaN         solar     0.000    0.0  0.044
# 5624 2021-01-01       YZEURIN1  NaN         solar     0.000    0.0  0.102
#
#       min_q  max_q  rated_s  ...   i  voltage_level_id     bus_id  connected  \
# 0       NaN    NaN      NaN  ... NaN           .CTLHP3  .CTLHP3_0       True
# 1       NaN    NaN      NaN  ... NaN           .CTLHP3  .CTLHP3_1       True
# 2       NaN    NaN      NaN  ... NaN           ARGIAP3        NaN      False
# 3       0.0    0.0      NaN  ... NaN           ARGOEP4  ARGOEP4_0       True
# 4       NaN    NaN      NaN  ... NaN           ARGOEP4  ARGOEP4_0       True
# ...     ...    ...      ...  ...  ..               ...        ...        ...
# 5620    NaN    NaN      NaN  ... NaN           YQUELP4        NaN      False
# 5621    NaN    NaN      NaN  ... NaN           YVETOP4        NaN      False
# 5622    NaN    NaN      NaN  ... NaN           YVETOP4        NaN      False
# 5623    NaN    NaN      NaN  ... NaN           YZEURP3        NaN      False
# 5624    NaN    NaN      NaN  ... NaN           YZEURP3  YZEURP3_0       True
#
#      substation_id  nominal_v  region_code  disaggregation_weight  \
# 0            .CTLH       63.0           84               0.002712
# 1            .CTLH       63.0           84               0.002712
# 2            ARGIA       63.0           75               0.000000
# 3            ARGOE       90.0           32               0.000000
# 4            ARGOE       90.0           32               0.002907
# ...            ...        ...          ...                    ...
# 5620         YQUEL       90.0           28               0.000000
# 5621         YVETO       90.0           28               0.000000
# 5622         YVETO       90.0           28               0.000000
# 5623         YZEUR       63.0           84               0.000000
# 5624         YZEUR       63.0           84               0.017824
#
#      online_capacity_total actual_output_total
# 0                55.315300              2667.0
# 1                55.315300              2667.0
# 2                18.229900                 0.0
# 3                49.534698               372.0
# 4                49.534698               372.0
# ...                    ...                 ...
# 5620              0.510000                 0.0
# 5621              0.510000                 0.0
# 5622              0.510000                 0.0
# 5623              5.722600                 0.0
# 5624              5.722600                 0.0
#
# [5625 rows x 27 columns]

# %% [markdown]
# ## Injecting the data

# %% [markdown]
# To use this data in the powerflow, we will need to change the `target_p` column in the grid to match those in the injection data. Noting that the indexing on the injection (pandas) dataset is via the index number as default, and we must change it to the `id` in order to correctly match the generators to their injected power. You will notice that there is a multiplication factor of 100 present; this is due to the `target_p`s of this generator injection dataset being in per-units for a base power of 100MW. This is not the case for the `p0`s in the load injection dataset, which are given in MW.

# %%
df_inj_gen['target_p'] =  df_inj_gen['target_p'] *100

df_gens = grid.get_generators(attributes=['target_p']) 
df_gens.update(df_inj_gen.set_index('id'))
grid.update_generators(df=df_gens)

# %% [markdown]
# In much the same way, we can set the P values for our loads, and proceed with V and Q injection. In the case of this dataset, however, we do not have the V or Q data (you may check!). Nonetheless, we will be able to run a powerflow if we can come up with some feasible synthetic data. Below, we use synthetic Q for our loads by setting the load Q according to the corresponding load P, with a power factor of 0.98.

# %%
load_power_factor = 0.98 

df_inj_load['p0'] = df_inj_load['p0']
df_loads = grid.get_loads(attributes=['p0'])
df_loads.update(df_inj_load.set_index('id'))
grid.update_loads(df=df_loads)

df_inj_load['q0'] = df_inj_load['p0'] * np.sqrt( (1-load_power_factor**2)/load_power_factor)
df_loads = grid.get_loads(attributes=['q0'])
df_loads.update(df_inj_load.set_index('id'))
grid.update_loads(df=df_loads)

# %% [markdown]
# We must also use synthetic data for the generators. Generators can either be PV with a voltage regulator (and `voltage_regulator_on = True`) or PQ (with `voltage_regulator_on = False`). For the PQ generators we can take the same approach as for the loads, and for the PV, the nominal voltage (`nominal_v`) of the connected voltage level is a sensible choice.

# %%
gen_power_factor = 0.8

# PQ generators
df_inj_pqgens = df_inj_gen.loc[df_inj_gen['voltage_regulator_on'] == False]
df_inj_pqgens['target_q'] = df_inj_pqgens['target_p']* np.sqrt( (1-gen_power_factor**2)/gen_power_factor)
df_pqgens = grid.get_generators(attributes=['target_q']) 
df_pqgens.update(df_inj_pqgens.set_index('id'))
grid.update_generators(df=df_pqgens)

# PV generators
df_inj_pvgens = df_inj_gen.loc[df_inj_gen['voltage_regulator_on'] == True]

lookup_v = df_inj_bus.drop_duplicates(subset='voltage_level_id').set_index('voltage_level_id')['nominal_v'] # Get nominal_v for each voltage_level_id
df_inj_pvgens['target_v'] = df_inj_pvgens['voltage_level_id'].map(lookup_v)
df_pvgens = grid.get_generators(attributes=['target_v'])
df_pvgens.update(df_inj_pvgens.set_index('id'))
grid.update_generators(df=df_pvgens)

# %% [markdown]
# We can use the `.validate()` function on our grid to check if it is set up correctly such that we can run a powerflow.

# %%
grid.validate()
# Out:
# ---------------------------------------------------------------------------
# PyPowsyblError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 grid.validate()
#
# File c:\Python311\Lib\site-packages\pypowsybl\network\impl\network.py:5986, in Network.validate(self)
#    5972 def validate(self) -> ValidationLevel:
#    5973     """
#    5974     Validate the network.
#    5975
#    (...)   5984                                   with the configured minimum validation level.
#    5985     """
# -> 5986     return _pp.validate(self._handle)
#
# PyPowsyblError: Dangling line '.SOTEL62SOTEL': p0 is invalid

# %% [markdown]
# This error is telling us there is an issue with (at least one of) our dangling lines. Dangling lines are the interconnections at the periphery of our grid, connecting to buses outside of the RTE dataset. These can export (or import) active and reactive power from/to our grid, and so we must also inject this data into the grid. Below, we have decided to calculate the active power mismatch of the grid, and distribute this mismatch amongst the dangling lines, weighted by the inverse reactance of the line, motivated by the idea that lower impedance lines carry more power. We´ll also say that these dangling lines supply no reactive power.

# %%
df_dlines = grid.get_dangling_lines()

mismatch = grid.get_generators()['target_p'].sum() - grid.get_loads()['p0'].sum()
print(f"\nMismatch to distribute across {len(df_dlines)} dangling lines: {mismatch:.2f} MW")

df_dlines['weight'] = 1.0 / df_dlines['x'].replace(0, np.nan) 
df_dlines['p0'] = mismatch * df_dlines['weight'] / df_dlines['weight'].sum()              
df_dlines['q0'] = 0.0

grid.update_dangling_lines(df=df_dlines[['p0', 'q0']])
# Out:
# Mismatch to distribute across 45 dangling lines: 21956.99 MW

# %% [markdown]
# Now we can check again to see if we have all the required input data for the powerflow:

# %%
grid.validate()
# Out:
# <ValidationLevel.STEADY_STATE_HYPOTHESIS: 1>

# %% [markdown]
# This `STEADY_STATE_HYPOTHESIS` validation level is necessary for us to be able to run our powerflow.

# %% [markdown]
# ## Running the powerflow

# %% [markdown]
# We run the powerflow as below, and have a look at the results

# %%
results = pp.loadflow.run_ac(grid)
results
# Out:
# [ComponentResult(connected_component_num=0, synchronous_component_num=0, status=MAX_ITERATION_REACHED, status_text=Reached Newton-Raphson max iterations limit, iteration_count=16, reference_bus_id='CHAFFP7_0', slack_bus_results=[SlackBusResult(id='CHAFFP7_0', active_power_mismatch=33342.95481401203)], distributed_active_power=0.0)]

# %% [markdown]
# The `status` component of our results is telling us that the powerflow algorithm failed to converge. This is okay, as we still haven´t looked into the various ways we can choose to run the powerflow. We have a good degree of flexibility when it comes to this, having access to two providers:

# %%
pp.loadflow.get_provider_names()
#pp.loadflow.get_default_provider() #Run to check which is in use
# Out:
# ['DynaFlow', 'OpenLoadFlow']

# %% [markdown]
# We will use the default [OpenLoadFlow](https://powsybl.readthedocs.io/projects/powsybl-open-loadflow/en/latest/) provider, however [Dynawo](https://powsybl.readthedocs.io/projects/powsybl-dynawo/en/latest/) is another option.
#
# Now we can look at the parameters of our powerflow. The default ones are:

# %%
pp.loadflow.Parameters()
# Out:
# Parameters(voltage_init_mode=UNIFORM_VALUES, transformer_voltage_control_on=False, use_reactive_limits=True, phase_shifter_regulation_on=False, twt_split_shunt_admittance=False, shunt_compensator_voltage_control_on=False, read_slack_bus=True, write_slack_bus=True, distributed_slack=True, balance_type=PROPORTIONAL_TO_GENERATION_P_MAX, dc_use_transformer_ratio=True, countries_to_balance=[], component_mode=<ComponentMode.MAIN_CONNECTED: 0>, hvdc_ac_emulation=True, dc_power_factor=1.0, provider_parameters={})

# %% [markdown]
# We can leave these as is, but let´s change them in an effort to get convergence. In the script below you will see various changes to PowSyBl loadflow [parameters](https://powsybl.readthedocs.io/projects/powsybl-core/en/stable/simulation/loadflow/configuration.html) which should help our powerflow to converge.  There are long lists of 'provider parameters' which offer increased flexibility, and can be found on the corresponding provider´s documentation ( [Open Loadflow](https://powsybl.readthedocs.io/projects/powsybl-open-loadflow/en/latest/), [Dynawo](https://powsybl.readthedocs.io/projects/powsybl-dynawo/en/latest/)). It´s important to note that these provider parameters must be used as below, with all keys and values given as a string.

# %%
ac_params = pp.loadflow.Parameters(
    voltage_init_mode=pp.loadflow.VoltageInitMode.DC_VALUES, # Initialize voltages as 1pu and voltage angles using a DC powerflow
    distributed_slack=True, # The active power mismatch will be distributed over the network
    balance_type=pp.loadflow.BalanceType.PROPORTIONAL_TO_GENERATION_P, # The participation factors for slack distribution are calculated using 'target_p'
    transformer_voltage_control_on=False, # Transformer voltage regulating will not be allowed 
    shunt_compensator_voltage_control_on=False, # Shunt compensator voltage regulating will not be allowed 

    provider_parameters={ 
        'maxNewtonRaphsonIterations': '200',
        'maxOuterLoopIterations': '50',
        'stateVectorScalingMode': 'MAX_VOLTAGE_CHANGE',  # Limits voltage vector updates
        'maxVoltageChangeStateVectorScalingMaxDv': '0.05',  # Limits maximum voltage magnitude update amount
        'maxVoltageChangeStateVectorScalingMaxDphi': '0.08726',  # Limits maximum voltage angle update amount
        'maxSlackBusCount': '10', 
        'newtonRaphsonConvEpsPerEq': '1e-1', # Stopping criterion
        'slackBusPMaxMismatch': '500.0', # Slack power is considered to be distributed when below 500MW
    }
)

# %% [markdown]
# Now we´ll try to run the powerflow again, also producing a report alongside it:

# %%
rep = pp.report.ReportNode()
results = pp.loadflow.run_ac(grid, parameters= ac_params, report_node= rep )
rep # If we wish to read the report
# Out:
# +
#    + Load flow on network 'recollement-auto-20210101-0000-enrichi'
#       + Network CC0 SC0
#          7 generators were discarded from voltage control because not started
#          17 generators have been discarded from voltage control because of a too small reactive range
#          + Network info
#             Network has 6404 buses and 9405 branches
#             Network balance: active generation=84787.5248086825 MW, active load=82109.27629748559 MW, reactive generation=10589.658268868923 MVar, reactive load=12824.411425352097 MVar
#             Angle reference bus: CHAFFP7_0
#             Slack bus: CHAFFP7_0
#             Slack bus: TAVELP7_0
#             Slack bus: WARANP7_0
#             Slack bus: TERRIP7_0
#             Slack bus: VIGY P7_0
#             Slack bus: BARNAP7_0
#             Slack bus: CHESNP7_0
#             Slack bus: ARGOEP7_0
#             Slack bus: SSV.OP7_2
#             Slack bus: TABARP7_0
#          Slack bus active power (-2678.2485111975843 MW) distributed in 1 distribution iteration(s)
#          DC load flow completed (solverSuccess=true, outerloopStatus=STABLE)
#          Outer loop DistributedSlack
#          Outer loop VoltageMonitoring
#          + Outer loop ReactiveLimits
#             + Outer loop iteration 1
#                + 233 buses switched PV -> PQ (226 buses remain PV)
#                   Switch bus 'EGUZOP4_0' PV -> PQ, q=92.88875183453294 > maxQ=15.819999694824219
#                   Switch bus 'HOURAP1_0' PV -> PQ, q=-25.283713835070287 < minQ=-6.21999979019165
#                   Switch bus 'SSDALP3_1#0' PV -> PQ, q=36.086176016057195 > maxQ=4.833000183105469
#                   Switch bus 'DOMLOP6_0' PV -> PQ, q=385.4857132894128 > maxQ=280.527244781737
#                   Switch bus 'ALRANP3_0' PV -> PQ, q=-13.718804494044434 < minQ=-1.0
#                   Switch bus 'ARGENP3_0' PV -> PQ, q=122.4655175374692 > maxQ=5.400000095367432
#                   Switch bus 'ARJOMP4_0' PV -> PQ, q=54.28436996517358 > maxQ=2.0
#                   Switch bus 'ARLY P2_0' PV -> PQ, q=47.7673079005001 > maxQ=10.0
#                   Switch bus 'ARRENP5_0' PV -> PQ, q=-17.255522550772184 < minQ=-1.0
#                   Switch bus 'ASASPP3_0' PV -> PQ, q=35.747740855483116 > maxQ=1.0
#                   Switch bus 'AUCUNP5_0' PV -> PQ, q=-2.1931176241196226 < minQ=-1.8899999856948853
#                   Switch bus 'AUSSOP3_0' PV -> PQ, q=24.712238523007287 > maxQ=0.5
#                   Switch bus 'AVIG6P1_0' PV -> PQ, q=131.4658864054742 > maxQ=8.041998863220215
#                   Switch bus 'AVRIEP3_0' PV -> PQ, q=-4.484751308372381 < minQ=-3.4200000762939458
#                   Switch bus 'B.MESP6_0' PV -> PQ, q=-155.9443662963531 < minQ=-23.600000381469727
#                   Switch bus 'BAIGTP3_0' PV -> PQ, q=67.71692478694149 > maxQ=2.8399999141693115
#                   Switch bus 'BALANP3_0' PV -> PQ, q=58.675417974562194 > maxQ=3.982999801635742
#                   Switch bus 'BAOUSP3_0' PV -> PQ, q=-4.832424527721855 < minQ=-3.0
#                   Switch bus 'BARALP1_0' PV -> PQ, q=0.027510641362549215 < minQ=0.14000000059604645
#                   Switch bus 'BARALP3_0' PV -> PQ, q=-12.325981473446612 < minQ=-10.350000381469727
#                   Switch bus 'BATHIP6_0' PV -> PQ, q=-112.72112052023999 < minQ=-38.0
#                   Switch bus 'BENS P3_0' PV -> PQ, q=22.24487931959871 > maxQ=2.6700000762939453
#                   Switch bus 'BEYREP3_0' PV -> PQ, q=18.316758190884343 > maxQ=3.5999999046325684
#                   Switch bus 'BILHOP3_0' PV -> PQ, q=62.50615058559674 > maxQ=27.200000762939453
#                   Switch bus 'BIOGEP1_0' PV -> PQ, q=5.677325070898798 > maxQ=4.870000123977661
#                   Switch bus 'BIONNP3_0' PV -> PQ, q=128.77496878218375 > maxQ=3.0
#                   Switch bus 'BLYE P3_0' PV -> PQ, q=14.986014602989428 > maxQ=1.440000057220459
#                   Switch bus 'BOLOZP3_0' PV -> PQ, q=49.0322992461131 > maxQ=4.800000190734863
#                   Switch bus 'BORD5P3_0' PV -> PQ, q=15.084542778900593 > maxQ=5.0
#                   Switch bus 'BORDEP3_0' PV -> PQ, q=16.06404601152747 > maxQ=3.5899999141693115
#                   Switch bus 'BOUV5P3_0' PV -> PQ, q=61.21320262997722 > maxQ=6.0
#                   Switch bus 'BOZELP3_0' PV -> PQ, q=9.20296808236305 > maxQ=5.699999809265137
#                   Switch bus 'BRAEKP1_0' PV -> PQ, q=270.9072632732014 > maxQ=140.04400634765625
#                   Switch bus 'BRAEKP1_1' PV -> PQ, q=295.82599904583003 > maxQ=227.73300933837888
#                   Switch bus 'BREILP3_0' PV -> PQ, q=31.695326928097334 > maxQ=3.0
#                   Switch bus 'BRENSP1_0' PV -> PQ, q=37.94852210705283 > maxQ=31.531999588012695
#                   Switch bus 'BREVIP6_0' PV -> PQ, q=-27.189340761710312 < minQ=-13.916000366210938
#                   Switch bus 'BRIDOP3_0' PV -> PQ, q=10.28572881065859 > maxQ=4.056000232696533
#                   Switch bus 'BRUGAP3_0' PV -> PQ, q=7.763262512980873 > maxQ=1.0
#                   Switch bus 'BRUN5P3_0' PV -> PQ, q=-15.993890462721916 < minQ=-4.0
#                   Switch bus 'BXMONP1_0' PV -> PQ, q=33.23722408455509 > maxQ=12.530000686645506
#                   Switch bus 'BXVOIP1_0' PV -> PQ, q=11.235290477651477 > maxQ=9.342000007629395
#                   Switch bus 'BZNE P3_0' PV -> PQ, q=4.843271499964397 > maxQ=3.0
#                   Switch bus 'BZNILP1_0' PV -> PQ, q=15.616925863253089 > maxQ=13.77999997138977
#                   Switch bus 'BZNILP3_0' PV -> PQ, q=-22.956212555038125 < minQ=-7.5999999046325675
#                   Switch bus 'C.VILP1_0' PV -> PQ, q=84.38200258449183 > maxQ=47.39999914169311
#                   Switch bus 'CADARP1_0' PV -> PQ, q=13.058352068635104 > maxQ=3.5999999046325684
#                   Switch bus 'CADERP1_0' PV -> PQ, q=18.43926798322233 > maxQ=8.619999885559082
#                   Switch bus 'CADERP1_2' PV -> PQ, q=17.835764563247736 > maxQ=6.920000076293946
#                   Switch bus 'CAJARP1_0' PV -> PQ, q=8.373374338356987 > maxQ=2.8199996948242188
#                   Switch bus 'CALCEP3_0' PV -> PQ, q=14.195789186631913 > maxQ=10.0
#                   Switch bus 'CALYPP2_0' PV -> PQ, q=76.22174144702197 > maxQ=5.400000095367432
#                   Switch bus 'CAMBEP1_0' PV -> PQ, q=3.024923871999119 > maxQ=1.1200000047683716
#                   Switch bus 'CARBOP3_0' PV -> PQ, q=43.73768942403707 > maxQ=2.0
#                   Switch bus 'CASSAP3_0' PV -> PQ, q=10.265265890802766 > maxQ=4.0
#                   Switch bus 'CHAPEP4_0' PV -> PQ, q=76.14399796381258 > maxQ=38.96599936485291
#                   Switch bus 'CHAVAP3_0' PV -> PQ, q=10.072718866550545 > maxQ=2.369999885559082
#                   Switch bus 'CHEV5P6_0' PV -> PQ, q=369.6612689573124 > maxQ=276.67129902338615
#                   Switch bus 'CHEVRP3_0' PV -> PQ, q=16.777776475817063 > maxQ=12.0649995803833
#                   Switch bus 'CIERPP3_0' PV -> PQ, q=29.56550665387634 > maxQ=1.0
#                   Switch bus 'COUFFP1_0' PV -> PQ, q=35.36863153073252 > maxQ=27.229999954320405
#                   Switch bus 'CRAIEP1_0' PV -> PQ, q=13.550404156684381 > maxQ=7.582000017166138
#                   Switch bus 'CSLNAP1_0' PV -> PQ, q=20.051309285904892 > maxQ=13.748000144958498
#                   Switch bus 'CTLARP1_0' PV -> PQ, q=-4.325402758856869 < minQ=-1.0
#                   Switch bus 'CTLUSP4_0' PV -> PQ, q=57.54891680931635 > maxQ=3.0
#                   Switch bus 'CUS_PP1_0' PV -> PQ, q=12.316488723255414 > maxQ=4.31000018119812
#                   Switch bus 'CUS_PP1_1' PV -> PQ, q=6.508458465867273 > maxQ=4.28000020980835
#                   Switch bus 'CXTAGP3_0' PV -> PQ, q=7.692515387753218 > maxQ=1.1669998168945312
#                   Switch bus 'CXTAGP3_1' PV -> PQ, q=7.910761336906802 > maxQ=1.1650009155273438
#                   Switch bus 'CZBAIP3_0' PV -> PQ, q=23.335379483519155 > maxQ=7.058000087738037
#                   Switch bus 'DOUZEP4_0' PV -> PQ, q=-146.91978647206417 < minQ=-4.0
#                   Switch bus 'E.CONP3_0' PV -> PQ, q=-28.887489485737206 < minQ=-2.5
#                   Switch bus 'E.LESP1_0' PV -> PQ, q=9.13116283706892 > maxQ=3.190999984741211
#                   Switch bus 'ENCHAP6_0' PV -> PQ, q=-53.31768281471341 < minQ=-10.0
#                   Switch bus 'ESPALP3_0' PV -> PQ, q=56.85064179533583 > maxQ=1.0
#                   Switch bus 'ESPI5P6_0' PV -> PQ, q=15.817308147052245 > maxQ=11.0
#                   Switch bus 'ESQUEP1_0' PV -> PQ, q=2.477360088012736 > maxQ=2.0799999237060547
#                   Switch bus 'EYLIEP3_0' PV -> PQ, q=-13.869846901038585 < minQ=0.0
#                   Switch bus 'EYSSEP3_0' PV -> PQ, q=12.712711385432307 > maxQ=5.009999990463257
#                   Switch bus 'F.SULP4_0' PV -> PQ, q=22.76438213605843 > maxQ=5.149999618530273
#                   Switch bus 'FABIAP3_0' PV -> PQ, q=1.1851708779703003 > maxQ=1.0
#                   Switch bus 'FACT5P3_0' PV -> PQ, q=68.32737582459734 > maxQ=25.0
#                   Switch bus 'FADE5P3_0' PV -> PQ, q=4.506160288556771 > maxQ=1.0429999828338623
#                   Switch bus 'FAYETP1_0' PV -> PQ, q=6.587020524713207 > maxQ=6.25
#                   Switch bus 'FEISSP3_0' PV -> PQ, q=-5.7576491595341395 < minQ=-3.5899999141693115
#                   Switch bus 'FOS  P3_0' PV -> PQ, q=-4.571007205834121 < minQ=0.0
#                   Switch bus 'FTAN P3_0' PV -> PQ, q=-3.341236489985011 < minQ=-3.0000000000000004
#                   Switch bus 'FUMELP3_0' PV -> PQ, q=27.53760357092432 > maxQ=0.9200000166893006
#                   Switch bus 'G.QU6P4_0' PV -> PQ, q=82.66590461369242 > maxQ=2.948000192642212
#                   Switch bus 'G.RIVP6_0' PV -> PQ, q=-379.2107279405286 < minQ=-182.35000610351562
#                   Switch bus 'GAMBSP1_0' PV -> PQ, q=20.78333848773314 > maxQ=19.65999984741211
#                   Switch bus 'GAMBSP1_1' PV -> PQ, q=18.953613679309047 > maxQ=9.829999923706055
#                   Switch bus 'GARD6P1_0' PV -> PQ, q=14.346095374319253 > maxQ=4.800000190734863
#                   Switch bus 'GATELP4_0' PV -> PQ, q=107.95181886390309 > maxQ=10.391486167907713
#                   Switch bus 'GEDREP3_0' PV -> PQ, q=15.852506529082788 > maxQ=2.0
#                   Switch bus 'GENISP6_0' PV -> PQ, q=28.322147124345065 > maxQ=16.631999969482422
#                   Switch bus 'GENISP6_1' PV -> PQ, q=158.5819239932789 > maxQ=12.329999923706055
#                   Switch bus 'GENISP6_4' PV -> PQ, q=141.2928634344098 > maxQ=25.92000007629395
#                   Switch bus 'GENTIP3_0' PV -> PQ, q=6.248610893270978 > maxQ=1.0
#                   Switch bus 'GERSTP1_0' PV -> PQ, q=13.845814051178 > maxQ=5.468999862670898
#                   Switch bus 'GERSTP1_1' PV -> PQ, q=13.845814051178 > maxQ=5.468999862670898
#                   Switch bus 'GERSTP1_2' PV -> PQ, q=15.370008077436676 > maxQ=11.82900094985962
#                   Switch bus 'GERVAP1_0' PV -> PQ, q=22.480551026226504 > maxQ=9.070000648498535
#                   Switch bus 'GIFFRP3_0' PV -> PQ, q=158.7050005518904 > maxQ=2.0
#                   Switch bus 'GIROTP2_0' PV -> PQ, q=-3.199835579928134 < minQ=-2.7300000190734863
#                   Switch bus 'GLAIRP3_0' PV -> PQ, q=-0.11086035889684709 < minQ=0.0
#                   Switch bus 'GLORIP3_0' PV -> PQ, q=45.71191984756524 > maxQ=21.0
#                   Switch bus 'GOLFEP3_2' PV -> PQ, q=17.545742657533793 > maxQ=7.230000019073486
#                   Switch bus 'GOLINP6_0' PV -> PQ, q=-21.4956754754553 < minQ=-13.240001357456348
#                   Switch bus 'GRAN6P3_0' PV -> PQ, q=46.71697323811088 > maxQ=8.300000190734863
#                   Switch bus 'GRIPPP3_0' PV -> PQ, q=12.952123093896262 > maxQ=1.4900000095367432
#                   Switch bus 'GUER8P6_0' PV -> PQ, q=74.54269649567777 > maxQ=8.040000915527344
#                   Switch bus 'GUERLP3_0' PV -> PQ, q=-110.55696860868665 < minQ=-10.399999618530273
#                   Switch bus 'GUESDP6_0' PV -> PQ, q=99.43967416911619 > maxQ=90.625
#                   Switch bus 'HAUTEP4_0' PV -> PQ, q=-7.403856806221487 < minQ=-2.0
#                   Switch bus 'IRANGP1_0' PV -> PQ, q=29.328055389642678 > maxQ=15.299999713897705
#                   Switch bus 'IVRY5P3_0' PV -> PQ, q=78.5737303619328 > maxQ=16.5
#                   Switch bus 'JOUQUP3_0' PV -> PQ, q=34.44696577367496 > maxQ=16.77199935913086
#                   Switch bus 'JOURDP3_0' PV -> PQ, q=-8.990552659596851 < minQ=-5.099999904632568
#                   Switch bus 'JUSTIP6_0' PV -> PQ, q=27.368484620365052 > maxQ=20.25
#                   Switch bus 'L.ATHP1_0' PV -> PQ, q=0.6772775570945688 < minQ=1.0799999758601189
#                   Switch bus 'L.ATHP3_0' PV -> PQ, q=6.985595432234273 > maxQ=5.7729997634887695
#                   Switch bus 'L.CE1P3_0' PV -> PQ, q=16.05825112418087 > maxQ=9.020000457763672
#                   Switch bus 'L.CE2P1_0' PV -> PQ, q=78.43331878387761 > maxQ=47.96299934387206
#                   Switch bus 'L.MORP3_0' PV -> PQ, q=7.592504582602189 > maxQ=5.974999904632568
#                   Switch bus 'L.NEUP1_0' PV -> PQ, q=55.42126902244361 > maxQ=18.0
#                   Switch bus 'L.NEUP1_1' PV -> PQ, q=55.42126902244361 > maxQ=18.0
#                   Switch bus 'L.NEUP3_0' PV -> PQ, q=46.307260818972786 > maxQ=13.909999847412111
#                   Switch bus 'LARDIP6_0' PV -> PQ, q=8.834848428887199 > maxQ=6.940000057220459
#                   Switch bus 'LASSOP1_0' PV -> PQ, q=-10.10019337843957 < minQ=2.56000018119812
#                   Switch bus 'LAZERP3_0' PV -> PQ, q=25.309090067190887 > maxQ=5.0
#                   Switch bus 'LESTRP4_0' PV -> PQ, q=-28.495795629903053 < minQ=-16.0
#                   Switch bus 'LOUD8P3_0' PV -> PQ, q=-10.813421064563045 < minQ=-2.880000114440918
#                   Switch bus 'LOUP P3_0' PV -> PQ, q=38.68404030539327 > maxQ=3.0
#                   Switch bus 'LUMIEP3_0' PV -> PQ, q=46.98428921760751 > maxQ=8.399999618530273
#                   Switch bus 'LUZ  P3_0' PV -> PQ, q=11.376402451440185 > maxQ=7.900000333786012
#                   Switch bus 'LUZECP3_0' PV -> PQ, q=41.442798565041585 > maxQ=3.0
#                   Switch bus 'LUZI2P3_0' PV -> PQ, q=-24.19651100835143 < minQ=-8.849999904632568
#                   Switch bus 'M.NICP3_0' PV -> PQ, q=-14.112306677435072 < minQ=-8.0
#                   Switch bus 'M.TERP1_0' PV -> PQ, q=480.1787932327692 > maxQ=3.980000019073486
#                   Switch bus 'M.VIRP4_0' PV -> PQ, q=7.466728919920398 > maxQ=6.590000152587891
#                   Switch bus 'MADE6P6_0' PV -> PQ, q=-25.57142108817061 < minQ=-9.0
#                   Switch bus 'MAGDEP4_0' PV -> PQ, q=-54.33106502086957 < minQ=-13.260000228881836
#                   Switch bus 'MALA8P3_0' PV -> PQ, q=48.69165681216714 > maxQ=6.519999980926514
#                   Switch bus 'MALGOP6_0' PV -> PQ, q=264.63126979079703 > maxQ=66.14999771118164
#                   Switch bus 'MALLEP6_0' PV -> PQ, q=38.03822723797481 > maxQ=18.29400062561035
#                   Switch bus 'MARC5P4_0' PV -> PQ, q=18.901906241387945 > maxQ=6.191999435424805
#                   Switch bus 'MEAUXP3_0' PV -> PQ, q=70.09189499919125 > maxQ=9.0
#                   Switch bus 'MEES P1_0' PV -> PQ, q=10.835195683200084 > maxQ=8.019999980926514
#                   Switch bus 'MIMI5P1_0' PV -> PQ, q=12.418739616119263 > maxQ=7.199999809265137
#                   Switch bus 'MOTT6P3_0' PV -> PQ, q=126.23377698696459 > maxQ=1.0
#                   Switch bus 'MOTZ P1_0' PV -> PQ, q=20.413536149697727 > maxQ=6.0
#                   Switch bus 'MOUTIP3_0' PV -> PQ, q=5.046248591249736 > maxQ=1.7400000095367432
#                   Switch bus 'MOUX P3_0' PV -> PQ, q=14.981048684478537 > maxQ=8.0
#                   Switch bus 'MTAHUP6_0' PV -> PQ, q=-83.31192049062932 < minQ=7.469741821289058
#                   Switch bus 'MTFERP3_0' PV -> PQ, q=11.917120525239255 > maxQ=8.562000274658203
#                   Switch bus 'N.BRIP2_0' PV -> PQ, q=137.61330251515957 > maxQ=2.0
#                   Switch bus 'N.USSP4_0' PV -> PQ, q=30.823076946768424 > maxQ=1.0
#                   Switch bus 'NANTEP6_0' PV -> PQ, q=761.253820083782 > maxQ=225.1118187158943
#                   Switch bus 'NAUSSP3_0' PV -> PQ, q=6.60729589632183 > maxQ=4.5
#                   Switch bus 'NOUAUP5_0' PV -> PQ, q=8.9385170125297 > maxQ=1.0
#                   Switch bus 'OCHE P3_0' PV -> PQ, q=-1.7287066834882125 < minQ=-1.2000000476837158
#                   Switch bus 'ORELLP6_0' PV -> PQ, q=-56.29488146178119 < minQ=-14.199999809265137
#                   Switch bus 'OTTMAP1_0' PV -> PQ, q=-20.090175214338757 < minQ=-12.75
#                   Switch bus 'P.BENP1_1' PV -> PQ, q=3.6915829071642925 > maxQ=2.9099998474121094
#                   Switch bus 'P.BORP6_0' PV -> PQ, q=-77.16192694257948 < minQ=-61.55999755859375
#                   Switch bus 'P.CHAP4_0' PV -> PQ, q=50.60508809900273 > maxQ=35.029998779296875
#                   Switch bus 'P.ESCP1_0' PV -> PQ, q=20.914630996570136 > maxQ=5.0
#                   Switch bus 'P.HA5P6_0' PV -> PQ, q=262.72009327861633 > maxQ=83.6395546729827
#                   Switch bus 'P.LIGP3_0' PV -> PQ, q=49.056312087441256 > maxQ=0.6899999976158142
#                   Switch bus 'P.REIP3_0' PV -> PQ, q=-4.611078139950031 < minQ=-2.0
#                   Switch bus 'P.RH5P3_0' PV -> PQ, q=-24.93919182691441 < minQ=-4.619999885559082
#                   Switch bus 'P.RIVP3_0' PV -> PQ, q=17.213268149038186 > maxQ=1.8300000429153442
#                   Switch bus 'P.VARP3_0' PV -> PQ, q=33.694425954200995 > maxQ=1.0
#                   Switch bus 'P.VIZP3_0' PV -> PQ, q=34.413838850274026 > maxQ=13.079999923706055
#                   Switch bus 'PEBERP3_0' PV -> PQ, q=18.7804033495091 > maxQ=1.0
#                   Switch bus 'PRAT5P3_0' PV -> PQ, q=12.347066091413694 > maxQ=1.7599999904632568
#                   Switch bus 'PRESSP1_0' PV -> PQ, q=32.274347171533165 > maxQ=5.610000133514404
#                   Switch bus 'PROV6P1_0' PV -> PQ, q=-19.479965525443177 < minQ=-16.289999961853027
#                   Switch bus 'PTCH5P3_0' PV -> PQ, q=21.870172001374044 > maxQ=1.7599999904632568
#                   Switch bus 'RAMB5P3_0' PV -> PQ, q=66.60189865542634 > maxQ=1.0
#                   Switch bus 'RANCEP6_0' PV -> PQ, q=-72.84593613067045 < minQ=-23.200000762939453
#                   Switch bus 'RANCEP6_1' PV -> PQ, q=-68.16355839237076 < minQ=-23.200000762939453
#                   Switch bus 'RANCEP6_2' PV -> PQ, q=-64.64417479269287 < minQ=-24.799999237060547
#                   Switch bus 'RANDEP1_1' PV -> PQ, q=49.049943237994334 > maxQ=20.176000595092773
#                   Switch bus 'RAYNAP3_0' PV -> PQ, q=60.811835864564046 > maxQ=4.0
#                   Switch bus 'REVI5P7_0' PV -> PQ, q=79.94837333151281 > maxQ=69.36100006103516
#                   Switch bus 'REVI5P7_1' PV -> PQ, q=79.94837333151281 > maxQ=69.49199676513672
#                   Switch bus 'RIVI6P3_0' PV -> PQ, q=26.624741727594483 > maxQ=2.009999990463257
#                   Switch bus 'S.BREP1_0' PV -> PQ, q=11.671866577441392 > maxQ=10.580000400543213
#                   Switch bus 'S.CURP6_0' PV -> PQ, q=-89.01008637603809 < minQ=-17.39999771118164
#                   Switch bus 'S.SABP3_0' PV -> PQ, q=16.083846845830863 > maxQ=2.0
#                   Switch bus 'SAILLP1_0' PV -> PQ, q=8.718683216834355 > maxQ=4.099999785423279
#                   Switch bus 'SAKANP3_0' PV -> PQ, q=23.177947893087094 > maxQ=20.0
#                   Switch bus 'SALELP3_0' PV -> PQ, q=33.80358529843504 > maxQ=6.0
#                   Switch bus 'SALIGP6_0' PV -> PQ, q=33.39318127581237 > maxQ=9.920000076293945
#                   Switch bus 'SIAGNP3_0' PV -> PQ, q=53.048316366132376 > maxQ=4.0
#                   Switch bus 'SOULOP3_0' PV -> PQ, q=29.150900006395613 > maxQ=10.0
#                   Switch bus 'SSAUBP1_0' PV -> PQ, q=-57.83086645975048 < minQ=0.0
#                   Switch bus 'SSCRIP3_0' PV -> PQ, q=4.974542032824484 > maxQ=2.0
#                   Switch bus 'SSE.CP3_0' PV -> PQ, q=23.448336625011734 > maxQ=5.695000171661377
#                   Switch bus 'SSESTP3_0' PV -> PQ, q=46.96353387447832 > maxQ=2.0
#                   Switch bus 'SSFAUP3_0' PV -> PQ, q=58.79936580308822 > maxQ=3.528000116348266
#                   Switch bus 'SSGEOP3_0' PV -> PQ, q=-12.74091856406323 < minQ=-1.2200000286102295
#                   Switch bus 'SSHERP1_0' PV -> PQ, q=4.062188273949589 > maxQ=3.0
#                   Switch bus 'SSHILP1_0' PV -> PQ, q=15.592099575159862 > maxQ=8.880000114440918
#                   Switch bus 'SSJU5P3_0' PV -> PQ, q=5.350964767592316 > maxQ=2.0
#                   Switch bus 'SSLARP3_0' PV -> PQ, q=22.457052623508748 > maxQ=3.150000095367431
#                   Switch bus 'SSMC P1_0' PV -> PQ, q=4.451572482398247 > maxQ=3.779999544145062
#                   Switch bus 'SSMRIP1_0' PV -> PQ, q=2.7385630991220267 > maxQ=0.8500000238418579
#                   Switch bus 'STRASP1_1' PV -> PQ, q=-7.25780982001777 < minQ=-5.079999923706055
#                   Switch bus 'SULAUP1_0' PV -> PQ, q=12.349467124966338 > maxQ=10.478000164031982
#                   Switch bus 'TARTIP3_0' PV -> PQ, q=103.4441654074314 > maxQ=6.599999904632568
#                   Switch bus 'TEICHP3_0' PV -> PQ, q=9.636879662291875 > maxQ=1.8300000429153442
#                   Switch bus 'TEMPLP3_0' PV -> PQ, q=27.462626669695034 > maxQ=7.901999950408935
#                   Switch bus 'TOURBP6_0' PV -> PQ, q=469.7292120452154 > maxQ=279.1526009067683
#                   Switch bus 'TRAMEP1_0' PV -> PQ, q=17.89546999017421 > maxQ=10.390000343322754
#                   Switch bus 'TUCOYP1_0' PV -> PQ, q=11.842982654208313 > maxQ=7.160000085830689
#                   Switch bus 'TUILIP3_0' PV -> PQ, q=125.64744909027358 > maxQ=8.0
#                   Switch bus 'USSONP3_0' PV -> PQ, q=7.276819354056975 > maxQ=3.0999999046325684
#                   Switch bus 'V.BENP4_0' PV -> PQ, q=59.89859441824592 > maxQ=1.0
#                   Switch bus 'V.LOTP3_0' PV -> PQ, q=54.608490911216876 > maxQ=18.940000534057617
#                   Switch bus 'VALABP1_0' PV -> PQ, q=42.86007109475243 > maxQ=9.0
#                   Switch bus 'VALE7P3_0' PV -> PQ, q=10.990215267719131 > maxQ=1.0
#                   Switch bus 'VANELP1_0' PV -> PQ, q=11.61888326938215 > maxQ=6.159999847412109
#                   Switch bus 'VAUGOP4_0' PV -> PQ, q=-21.425829721139507 < minQ=-3.5199999809265137
#                   Switch bus 'VENTHP2_0' PV -> PQ, q=104.52874122529465 > maxQ=2.380000114440918
#                   Switch bus 'VERN7P3_0' PV -> PQ, q=26.071913570283378 > maxQ=6.800000190734863
#                   Switch bus 'VERR5P1_0' PV -> PQ, q=12.066167348644438 > maxQ=10.13599967956543
#                   Switch bus 'VERSIP3_0' PV -> PQ, q=27.675164672253594 > maxQ=7.622000217437744
#                   Switch bus 'VINTRP3_0' PV -> PQ, q=-8.198512106820832 < minQ=-3.0
#                   Switch bus 'VLEREP3_0' PV -> PQ, q=43.84436356771744 > maxQ=18.0
#                   Switch bus 'VOGEHP1_0' PV -> PQ, q=15.886620088620257 > maxQ=15.866000175476074
#             + Outer loop iteration 2
#                + 40 buses switched PV -> PQ (186 buses remain PV)
#                   Switch bus 'ANDR5P1_0' PV -> PQ, q=1.3033406633645246 > maxQ=1.100000023841858
#                   Switch bus 'ANNIBP3_0' PV -> PQ, q=22.92803482802981 > maxQ=21.0
#                   Switch bus 'ARLOSP3_0' PV -> PQ, q=7.277331042377 > maxQ=5.0
#                   Switch bus 'AVEILP3_0' PV -> PQ, q=3.969101276200959 > maxQ=2.240000009536743
#                   Switch bus 'BANCAP3_0' PV -> PQ, q=23.426050068353625 > maxQ=15.03000068664551
#                   Switch bus 'BVIL6P2_0' PV -> PQ, q=25.723180234911958 > maxQ=22.0
#                   Switch bus 'BXFORP2_0' PV -> PQ, q=13.25151466032879 > maxQ=11.5
#                   Switch bus 'BZELIP3_0' PV -> PQ, q=7.650726834062382 > maxQ=5.0
#                   Switch bus 'CAMONP3_0' PV -> PQ, q=19.07752145430006 > maxQ=3.0
#                   Switch bus 'COINDP1_0' PV -> PQ, q=8.684847161073339 > maxQ=5.989999771118164
#                   Switch bus 'CUS_PP1_2' PV -> PQ, q=5.530457302262093 > maxQ=5.350000262260437
#                   Switch bus 'EDGARP4_0' PV -> PQ, q=11.1780400781754 > maxQ=8.255001068115234
#                   Switch bus 'F.ABEP1_0' PV -> PQ, q=5.096239072518119 > maxQ=2.412999987602234
#                   Switch bus 'GENISP6_5' PV -> PQ, q=63.068284198607216 > maxQ=27.30999946594238
#                   Switch bus 'GERVAP3_0' PV -> PQ, q=3.1325176045044145 > maxQ=1.1520004272460938
#                   Switch bus 'GETEUP1_0' PV -> PQ, q=2.665737238806576 > maxQ=1.0
#                   Switch bus 'GLANDP1_0' PV -> PQ, q=2.6886667869678478 > maxQ=2.0
#                   Switch bus 'GOLFEP3_0' PV -> PQ, q=22.437899035863666 > maxQ=14.460000038146973
#                   Switch bus 'ISSY P3_0' PV -> PQ, q=30.05441966453014 > maxQ=23.059999465942383
#                   Switch bus 'L.BALP1_0' PV -> PQ, q=4.699360658427868 > maxQ=4.31000018119812
#                   Switch bus 'M.BLAP3_0' PV -> PQ, q=13.408212260402367 > maxQ=2.299999952316284
#                   Switch bus 'M.MAUP3_0' PV -> PQ, q=-1.7065178519786173 < minQ=-1.0
#                   Switch bus 'MARCOP1_0' PV -> PQ, q=10.064796515732 > maxQ=8.800000190734863
#                   Switch bus 'MIZOEP3_0' PV -> PQ, q=5.291328634609727 > maxQ=3.0
#                   Switch bus 'NENTIP5_0' PV -> PQ, q=23.075310090699475 > maxQ=18.86299991607666
#                   Switch bus 'ORAISP6_0' PV -> PQ, q=23.79555045466475 > maxQ=21.266000747680664
#                   Switch bus 'ORGEIP3_0' PV -> PQ, q=5.083126312485575 > maxQ=1.5399999618530273
#                   Switch bus 'P.BENP1_0' PV -> PQ, q=8.664044612863187 > maxQ=7.3849992752075195
#                   Switch bus 'P.ROUP6_0' PV -> PQ, q=173.7488248768903 > maxQ=165.60256899948516
#                   Switch bus 'PELADP6_0' PV -> PQ, q=37.03176766175602 > maxQ=14.000000000000002
#                   Switch bus 'POM.CP3_0' PV -> PQ, q=17.61601292520254 > maxQ=4.28000020980835
#                   Switch bus 'RAGEAP3_0' PV -> PQ, q=8.71214719636555 > maxQ=3.1600000858306885
#                   Switch bus 'SSESTP6_0' PV -> PQ, q=34.99613425542254 > maxQ=23.799999237060547
#                   Switch bus 'SSTULP6_0' PV -> PQ, q=80.61243079789398 > maxQ=21.222999572753906
#                   Switch bus 'TEIL2P3_0' PV -> PQ, q=12.718312067385895 > maxQ=9.718999862670898
#                   Switch bus 'VALLIP1_0' PV -> PQ, q=2.9720102555234496 > maxQ=2.5999999046325684
#                   Switch bus 'VAUG5P1_0' PV -> PQ, q=9.56778899923929 > maxQ=8.179999828338623
#                   Switch bus 'VAUG5P1_1' PV -> PQ, q=9.56778899923929 > maxQ=8.179999828338623
#                   Switch bus 'VICLAP1_0' PV -> PQ, q=9.165339783289175 > maxQ=7.27999997138977
#                   Switch bus 'VLARDP2_0' PV -> PQ, q=12.98207138885914 > maxQ=3.0
#                + 22 buses switched PQ -> PV (0 buses blocked PQ due to the max number of switches)
#                   Switch bus 'HOURAP1_0' PQ -> PV, q=minQ and v=19.60202925169532kV < targetV=20.0kV
#                   Switch bus 'ARRENP5_0' PQ -> PV, q=minQ and v=149.21631145621942kV < targetV=150.0kV
#                   Switch bus 'AUCUNP5_0' PQ -> PV, q=minQ and v=149.16347500358714kV < targetV=150.0kV
#                   Switch bus 'AVRIEP3_0' PQ -> PV, q=minQ and v=61.702350694197655kV < targetV=63.0kV
#                   Switch bus 'BARALP1_0' PQ -> PV, q=minQ and v=19.29875989788784kV < targetV=20.0kV
#                   Switch bus 'BARALP3_0' PQ -> PV, q=minQ and v=60.74266860296009kV < targetV=63.0kV
#                   Switch bus 'BATHIP6_0' PQ -> PV, q=minQ and v=222.66603580806606kV < targetV=225.0kV
#                   Switch bus 'BREVIP6_0' PQ -> PV, q=minQ and v=220.47601489374622kV < targetV=225.0kV
#                   Switch bus 'COUFFP1_0' PQ -> PV, q=maxQ and v=20.039472803943795kV > targetV=20.0kV
#                   Switch bus 'CTLARP1_0' PQ -> PV, q=minQ and v=19.305780242212894kV < targetV=20.0kV
#                   Switch bus 'ENCHAP6_0' PQ -> PV, q=minQ and v=224.71854584098352kV < targetV=225.0kV
#                   Switch bus 'FEISSP3_0' PQ -> PV, q=minQ and v=61.739355004846004kV < targetV=63.0kV
#                   Switch bus 'FTAN P3_0' PQ -> PV, q=minQ and v=60.47310983521091kV < targetV=63.0kV
#                   Switch bus 'GLAIRP3_0' PQ -> PV, q=minQ and v=62.255854622632945kV < targetV=63.0kV
#                   Switch bus 'GOLINP6_0' PQ -> PV, q=minQ and v=224.85738617707042kV < targetV=225.0kV
#                   Switch bus 'L.ATHP1_0' PQ -> PV, q=minQ and v=19.047646708824143kV < targetV=20.0kV
#                   Switch bus 'ORELLP6_0' PQ -> PV, q=minQ and v=222.69572293952749kV < targetV=225.0kV
#                   Switch bus 'P.BORP6_0' PQ -> PV, q=minQ and v=224.9966596354635kV < targetV=225.0kV
#                   Switch bus 'P.REIP3_0' PQ -> PV, q=minQ and v=62.25593193038493kV < targetV=63.0kV
#                   Switch bus 'TRAMEP1_0' PQ -> PV, q=maxQ and v=20.24842369537kV > targetV=20.0kV
#                   Switch bus 'USSONP3_0' PQ -> PV, q=maxQ and v=63.0224252269605kV > targetV=63.0kV
#                   Switch bus 'VOGEHP1_0' PQ -> PV, q=maxQ and v=20.011669419144226kV > targetV=20.0kV
#             + Outer loop iteration 3
#                + 20 buses switched PV -> PQ (188 buses remain PV)
#                   Switch bus 'HOURAP1_0' PV -> PQ, q=-18.44769631433566 < minQ=-6.21999979019165
#                   Switch bus 'ARRENP5_0' PV -> PQ, q=-11.560494879474682 < minQ=-1.0
#                   Switch bus 'AUCUNP5_0' PV -> PQ, q=-1.958716849660947 < minQ=-1.8899999856948853
#                   Switch bus 'AVRIEP3_0' PV -> PQ, q=-3.968782161479175 < minQ=-3.4200000762939458
#                   Switch bus 'BARALP1_0' PV -> PQ, q=0.06669714291240045 < minQ=0.14000000059604645
#                   Switch bus 'BARALP3_0' PV -> PQ, q=-11.523985702473198 < minQ=-10.350000381469727
#                   Switch bus 'BATHIP6_0' PV -> PQ, q=-78.99555934315387 < minQ=-38.0
#                   Switch bus 'COUFFP1_0' PV -> PQ, q=32.49034194238117 > maxQ=27.229999954320405
#                   Switch bus 'CTLARP1_0' PV -> PQ, q=-3.113647707540987 < minQ=-1.0
#                   Switch bus 'ENCHAP6_0' PV -> PQ, q=-37.94421718050136 < minQ=-10.0
#                   Switch bus 'FEISSP3_0' PV -> PQ, q=-4.08473028028846 < minQ=-3.5899999141693115
#                   Switch bus 'GLAIRP3_0' PV -> PQ, q=-0.049930454367705324 < minQ=0.0
#                   Switch bus 'GOLINP6_0' PV -> PQ, q=-18.561914124232253 < minQ=-13.240001357456348
#                   Switch bus 'L.ATHP1_0' PV -> PQ, q=0.8548305451245732 < minQ=1.0799999758601189
#                   Switch bus 'ORELLP6_0' PV -> PQ, q=-40.029077469308696 < minQ=-14.199999809265137
#                   Switch bus 'P.BORP6_0' PV -> PQ, q=-71.6500174745628 < minQ=-61.55999755859375
#                   Switch bus 'P.REIP3_0' PV -> PQ, q=-3.5713927424621548 < minQ=-2.0
#                   Switch bus 'TRAMEP1_0' PV -> PQ, q=15.239239727311398 > maxQ=10.390000343322754
#                   Switch bus 'USSONP3_0' PV -> PQ, q=5.795861744716209 > maxQ=3.0999999046325684
#                   Switch bus 'VOGEHP1_0' PV -> PQ, q=15.88794476111978 > maxQ=15.866000175476074
#                + 6 buses switched PQ -> PV (0 buses blocked PQ due to the max number of switches)
#                   Switch bus 'EDGARP4_0' PQ -> PV, q=maxQ and v=90.00041880365474kV > targetV=90.0kV
#                   Switch bus 'F.ABEP1_0' PQ -> PV, q=maxQ and v=20.000523586025984kV > targetV=20.0kV
#                   Switch bus 'FOS  P3_0' PQ -> PV, q=minQ and v=62.993092560291196kV < targetV=63.0kV
#                   Switch bus 'GIROTP2_0' PQ -> PV, q=minQ and v=44.991831691427436kV < targetV=45.0kV
#                   Switch bus 'M.MAUP3_0' PQ -> PV, q=minQ and v=62.98538349351166kV < targetV=63.0kV
#                   Switch bus 'OCHE P3_0' PQ -> PV, q=minQ and v=62.999720403297204kV < targetV=63.0kV
#             + Outer loop iteration 4
#                + 7 buses switched PV -> PQ (187 buses remain PV)
#                   Switch bus 'BREVIP6_0' PV -> PQ, q=-22.57893284022085 < minQ=-13.916000366210938
#                   Switch bus 'EDGARP4_0' PV -> PQ, q=11.226119187643343 > maxQ=8.255001068115234
#                   Switch bus 'F.ABEP1_0' PV -> PQ, q=5.098763816611693 > maxQ=2.412999987602234
#                   Switch bus 'FOS  P3_0' PV -> PQ, q=-2.911780642520419 < minQ=0.0
#                   Switch bus 'GIROTP2_0' PV -> PQ, q=-3.2504344392182314 < minQ=-2.7300000190734863
#                   Switch bus 'M.MAUP3_0' PV -> PQ, q=-1.6985720069441097 < minQ=-1.0
#                   Switch bus 'OCHE P3_0' PV -> PQ, q=-1.539966196145976 < minQ=-1.2000000476837158
#                + 25 buses switched PQ -> PV (0 buses blocked PQ due to the max number of switches)
#                   Switch bus 'HOURAP1_0' PQ -> PV, q=minQ and v=19.60170067874699kV < targetV=20.0kV
#                   Switch bus 'ANDR5P1_0' PQ -> PV, q=maxQ and v=20.007519946841754kV > targetV=20.0kV
#                   Switch bus 'ARRENP5_0' PQ -> PV, q=minQ and v=149.21268661376772kV < targetV=150.0kV
#                   Switch bus 'AUCUNP5_0' PQ -> PV, q=minQ and v=149.15986805185497kV < targetV=150.0kV
#                   Switch bus 'AVRIEP3_0' PQ -> PV, q=minQ and v=61.74144061750961kV < targetV=63.0kV
#                   Switch bus 'BARALP1_0' PQ -> PV, q=minQ and v=19.29874684963075kV < targetV=20.0kV
#                   Switch bus 'BARALP3_0' PQ -> PV, q=minQ and v=60.742638647019504kV < targetV=63.0kV
#                   Switch bus 'BATHIP6_0' PQ -> PV, q=minQ and v=222.88340768321623kV < targetV=225.0kV
#                   Switch bus 'COUFFP1_0' PQ -> PV, q=maxQ and v=20.039032424925658kV > targetV=20.0kV
#                   Switch bus 'CTLARP1_0' PQ -> PV, q=minQ and v=19.31854512338139kV < targetV=20.0kV
#                   Switch bus 'ENCHAP6_0' PQ -> PV, q=minQ and v=224.7174711107757kV < targetV=225.0kV
#                   Switch bus 'FEISSP3_0' PQ -> PV, q=minQ and v=61.82762997368352kV < targetV=63.0kV
#                   Switch bus 'GLAIRP3_0' PQ -> PV, q=minQ and v=62.25562458083252kV < targetV=63.0kV
#                   Switch bus 'GLANDP1_0' PQ -> PV, q=maxQ and v=20.00673031100405kV > targetV=20.0kV
#                   Switch bus 'GOLINP6_0' PQ -> PV, q=minQ and v=224.8563814778907kV < targetV=225.0kV
#                   Switch bus 'L.ATHP1_0' PQ -> PV, q=minQ and v=19.047612044785797kV < targetV=20.0kV
#                   Switch bus 'ORELLP6_0' PQ -> PV, q=minQ and v=222.8330520464169kV < targetV=225.0kV
#                   Switch bus 'P.BORP6_0' PQ -> PV, q=minQ and v=224.99686628300555kV < targetV=225.0kV
#                   Switch bus 'P.REIP3_0' PQ -> PV, q=minQ and v=62.2556412143436kV < targetV=63.0kV
#                   Switch bus 'POM.CP3_0' PQ -> PV, q=maxQ and v=63.018159847666126kV > targetV=63.0kV
#                   Switch bus 'RAGEAP3_0' PQ -> PV, q=maxQ and v=63.017610487819304kV > targetV=63.0kV
#                   Switch bus 'TRAMEP1_0' PQ -> PV, q=maxQ and v=20.247457956098984kV > targetV=20.0kV
#                   Switch bus 'USSONP3_0' PQ -> PV, q=maxQ and v=63.022293090908846kV > targetV=63.0kV
#                   Switch bus 'VICLAP1_0' PQ -> PV, q=maxQ and v=20.001243936206098kV > targetV=20.0kV
#                   Switch bus 'VOGEHP1_0' PQ -> PV, q=maxQ and v=20.012616466689813kV > targetV=20.0kV
#             + Outer loop iteration 5
#                + 24 buses switched PV -> PQ (188 buses remain PV)
#                   Switch bus 'HOURAP1_0' PV -> PQ, q=-18.331216389882986 < minQ=-6.21999979019165
#                   Switch bus 'ANDR5P1_0' PV -> PQ, q=1.3766180604326688 > maxQ=1.100000023841858
#                   Switch bus 'ARRENP5_0' PV -> PQ, q=-11.53633458990812 < minQ=-1.0
#                   Switch bus 'AVRIEP3_0' PV -> PQ, q=-3.858968091344962 < minQ=-3.4200000762939458
#                   Switch bus 'BARALP1_0' PV -> PQ, q=0.06675801756911592 < minQ=0.14000000059604645
#                   Switch bus 'BARALP3_0' PV -> PQ, q=-11.46056557052331 < minQ=-10.350000381469727
#                   Switch bus 'BATHIP6_0' PV -> PQ, q=-51.58311757112989 < minQ=-38.0
#                   Switch bus 'BATHIP7_0' PV -> PQ, q=86.617245267405 > maxQ=65.52599716186523
#                   Switch bus 'COUFFP1_0' PV -> PQ, q=32.461148619803396 > maxQ=27.229999954320405
#                   Switch bus 'CTLARP1_0' PV -> PQ, q=-3.057321133915172 < minQ=-1.0
#                   Switch bus 'ENCHAP6_0' PV -> PQ, q=-37.78718169973265 < minQ=-10.0
#                   Switch bus 'GLAIRP3_0' PV -> PQ, q=-0.03751474867165561 < minQ=0.0
#                   Switch bus 'GLANDP1_0' PV -> PQ, q=2.8029799120921712 > maxQ=2.0
#                   Switch bus 'GOLINP6_0' PV -> PQ, q=-18.532353684433286 < minQ=-13.240001357456348
#                   Switch bus 'L.ATHP1_0' PV -> PQ, q=0.8756995956120414 < minQ=1.0799999758601189
#                   Switch bus 'ORELLP6_0' PV -> PQ, q=-35.06955702977897 < minQ=-14.199999809265137
#                   Switch bus 'P.BORP6_0' PV -> PQ, q=-71.57654465216496 < minQ=-61.55999755859375
#                   Switch bus 'P.REIP3_0' PV -> PQ, q=-3.4980695582689236 < minQ=-2.0
#                   Switch bus 'POM.CP3_0' PV -> PQ, q=21.655657024437943 > maxQ=4.28000020980835
#                   Switch bus 'RAGEAP3_0' PV -> PQ, q=10.594255858051243 > maxQ=3.1600000858306885
#                   Switch bus 'TRAMEP1_0' PV -> PQ, q=15.21392330844643 > maxQ=10.390000343322754
#                   Switch bus 'USSONP3_0' PV -> PQ, q=5.77903953375529 > maxQ=3.0999999046325684
#                   Switch bus 'VICLAP1_0' PV -> PQ, q=10.403255416952781 > maxQ=7.27999997138977
#                   Switch bus 'VOGEHP1_0' PV -> PQ, q=15.930462620373763 > maxQ=15.866000175476074
#                + 6 buses switched PQ -> PV (0 buses blocked PQ due to the max number of switches)
#                   Switch bus 'BREVIP6_0' PQ -> PV, q=minQ and v=218.4867411583045kV < targetV=225.0kV
#                   Switch bus 'F.ABEP1_0' PQ -> PV, q=maxQ and v=20.00081468394352kV > targetV=20.0kV
#                   Switch bus 'FOS  P3_0' PQ -> PV, q=minQ and v=62.984983563800576kV < targetV=63.0kV
#                   Switch bus 'GIROTP2_0' PQ -> PV, q=minQ and v=44.95853267491051kV < targetV=45.0kV
#                   Switch bus 'M.MAUP3_0' PQ -> PV, q=minQ and v=62.97729899046296kV < targetV=63.0kV
#                   Switch bus 'OCHE P3_0' PQ -> PV, q=minQ and v=62.99158371891323kV < targetV=63.0kV
#             + Outer loop iteration 6
#                + 7 buses switched PV -> PQ (187 buses remain PV)
#                   Switch bus 'BREVIP6_0' PV -> PQ, q=-39.61749977898242 < minQ=-13.916000366210938
#                   Switch bus 'F.ABEP1_0' PV -> PQ, q=5.198037125737185 > maxQ=2.412999987602234
#                   Switch bus 'FOS  P3_0' PV -> PQ, q=-2.5614260600893033 < minQ=0.0
#                   Switch bus 'GERVAP3_1' PV -> PQ, q=1.501222416964243 > maxQ=1.4800004959106445
#                   Switch bus 'GIROTP2_0' PV -> PQ, q=-3.448971238721034 < minQ=-2.7300000190734863
#                   Switch bus 'M.MAUP3_0' PV -> PQ, q=-1.6588647710498974 < minQ=-1.0
#                   Switch bus 'OCHE P3_0' PV -> PQ, q=-1.4773950797465722 < minQ=-1.2000000476837158
#                + 6 buses switched PQ -> PV (18 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'ANDR5P1_0' PQ -> PV, q=maxQ and v=20.029172677557547kV > targetV=20.0kV
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'BATHIP7_0' PQ -> PV, q=maxQ and v=380.50838648770446kV > targetV=380.0kV
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'GLANDP1_0' PQ -> PV, q=maxQ and v=20.02275233198524kV > targetV=20.0kV
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'POM.CP3_0' PQ -> PV, q=maxQ and v=63.10201613373522kV > targetV=63.0kV
#                   Switch bus 'RAGEAP3_0' PQ -> PV, q=maxQ and v=63.10020066305428kV > targetV=63.0kV
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'VICLAP1_0' PQ -> PV, q=maxQ and v=20.030393235723388kV > targetV=20.0kV
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 7
#                + 6 buses switched PV -> PQ (187 buses remain PV)
#                   Switch bus 'ANDR5P1_0' PV -> PQ, q=1.281509690507074 > maxQ=1.100000023841858
#                   Switch bus 'FEISSP3_0' PV -> PQ, q=-4.667592238945158 < minQ=-3.5899999141693115
#                   Switch bus 'GLANDP1_0' PV -> PQ, q=2.617098730274295 > maxQ=2.0
#                   Switch bus 'POM.CP3_0' PV -> PQ, q=18.25001508726709 > maxQ=4.28000020980835
#                   Switch bus 'RAGEAP3_0' PV -> PQ, q=8.976663923376245 > maxQ=3.1600000858306885
#                   Switch bus 'VICLAP1_0' PV -> PQ, q=9.53696983140106 > maxQ=7.27999997138977
#                + 2 buses switched PQ -> PV (23 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'GENISP6_5' PQ -> PV, q=maxQ and v=225.00674041703607kV > targetV=225.0kV
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'VALLIP1_0' PQ -> PV, q=maxQ and v=20.004938893928617kV > targetV=20.0kV
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 8
#                + 4 buses switched PV -> PQ (185 buses remain PV)
#                   Switch bus 'BATHIP7_0' PV -> PQ, q=116.18459338453727 > maxQ=65.52599716186523
#                   Switch bus 'GENISP6_5' PV -> PQ, q=79.43826666311342 > maxQ=27.30999946594238
#                   Switch bus 'SSCANP4_0' PV -> PQ, q=23.80477673951873 > maxQ=23.701000213623047
#                   Switch bus 'VALLIP1_0' PV -> PQ, q=3.899504062723346 > maxQ=2.5999999046325684
#                + 0 buses switched PQ -> PV (24 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FEISSP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 9
#                + 3 buses switched PQ -> PV (24 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
# ...
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'POM.CP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'RAGEAP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VALLIP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 21
#                + 1 buses switched PQ -> PV (27 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ALLEMP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP7_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'EYLIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FEISSP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Switch bus 'HAUTEP4_0' PQ -> PV, q=minQ and v=89.98357034493553kV < targetV=90.0kV
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 22
#                + 1 buses switched PV -> PQ (180 buses remain PV)
#                   Switch bus 'HAUTEP4_0' PV -> PQ, q=-4.31625173577008 < minQ=-2.0
#                + 0 buses switched PQ -> PV (36 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ALLEMP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ANDR5P1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP7_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'EYLIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FEISSP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_5' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLANDP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'MOUTIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'POM.CP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'RAGEAP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VALLIP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VICLAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#             + Outer loop iteration 23
#                + 0 buses switched PQ -> PV (37 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ALLEMP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ANDR5P1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP7_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'EYLIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FEISSP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_5' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLANDP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'HAUTEP4_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'MOUTIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'POM.CP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'RAGEAP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VALLIP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VICLAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#          Outer loop DistributedSlack
#          Outer loop VoltageMonitoring
#          + Outer loop ReactiveLimits
#             + Outer loop iteration 23
#                + 0 buses switched PQ -> PV (37 buses blocked PQ due to the max number of switches)
#                   Bus 'HOURAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ALLEMP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ANDR5P1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ARRENP5_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'AVRIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BARALP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BATHIP7_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'BREVIP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'COUFFP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'CTLARP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ENCHAP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'EYLIEP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FEISSP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'FOS  P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GENISP6_5' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GIROTP2_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLAIRP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GLANDP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'GOLINP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'HAUTEP4_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'L.ATHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'M.MAUP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'MOUTIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'OCHE P3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'ORELLP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.BORP6_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'P.REIP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'POM.CP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'RAGEAP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'TRAMEP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'USSONP3_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VALLIP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VICLAP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#                   Bus 'VOGEHP1_0' blocked PQ as it has reached its max number of PQ -> PV switch (3)
#          AC load flow completed successfully (solverStatus=CONVERGED, outerloopStatus=STABLE)

# %% [markdown]
# The loadflow converged! We can look at a few key pieces of information from `results` if we choose. The more interesting information, however, will come from inspecting our grid post-powerflow.

# %%
print(f"Status: {results[0].status_text}")
print(f"Iteration count: {results[0].iteration_count}")
print(f"Active power mismatch: {results[0].slack_bus_results[0].active_power_mismatch:.4f} MW")

df_buses = grid.get_buses()
df_vlevels = grid.get_voltage_levels()
df_buses = df_buses.merge(df_vlevels[['nominal_v']], left_on='voltage_level_id', right_index=True)
df_buses['v_pu'] = df_buses['v_mag'] / df_buses['nominal_v']

print(f"\n--- Bus Voltage Results ---")
print(f"Total buses: {len(df_buses)}")
print(f"\nVoltage magnitude (kV):")
print(df_buses['v_mag'].describe().to_string())
print(f"\nVoltage magnitude (pu):")
print(df_buses['v_pu'].describe().to_string())

out_of_range = df_buses[(df_buses['v_pu'] < 0.9) | (df_buses['v_pu'] > 1.1)]
print(f"\nBuses outside 0.9-1.1 pu: {len(out_of_range)} / {len(df_buses)}")
# Out:
# Status: Converged
# Iteration count: 219
# Active power mismatch: 10.7794 MW
#
# --- Bus Voltage Results ---
# Total buses: 6467
#
# Voltage magnitude (kV):
# count    6366.000000
# mean      112.720679
# std        90.787988
# min        14.362402
# 25%        59.690563
# 50%        63.154645
# 75%       149.214370
# max       414.858389
#
# Voltage magnitude (pu):
# count    6366.000000
# mean        0.971562
# std         0.047715
# min         0.532492
# 25%         0.946121
# 50%         0.976688
# 75%         0.999949
# max         1.256519
#
# Buses outside 0.9-1.1 pu: 438 / 6467
