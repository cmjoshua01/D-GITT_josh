# %% [markdown]
# # Other elements
#
# We presented some basic elements that may be relevant, but more detailed explanations on how each function to create elements can be found in the official documentation. In the [Network page](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/network.html) of the documentation, one can find all the possible element addition, modification or removal function possible, while in the following table one can have easy access to the creation function for the most relevant elements.

# %% [markdown]
# | Element / Component           | Creation Method                             | Documentation Link |
# |------------------------------|----------------------------------------------|---------------------|
# | Line                         | `Network.create_lines(...)`                  | [create_lines](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_lines.html#pypowsybl.network.Network.create_lines) |
# | Dangling Line                | `Network.create_dangling_lines(...)`         | [create_dangling_lines](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_dangling_lines.html#pypowsybl.network.Network.create_dangling_lines) |
# | Load                         | `Network.create_loads(...)`                  | [create_loads](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_loads.html#pypowsybl.network.Network.create_loads) |
# | Generator                    | `Network.create_generators(...)`            | [create_generators](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_generators.html#pypowsybl.network.Network.create_generators) |
# | 2-winding Transformer        | `Network.create_2_windings_transformers(...)`| [create_2_windings_transformers](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_2_windings_transformers.html#pypowsybl.network.Network.create_2_windings_transformers) |
# | HVDC Line                    | `Network.create_hvdc_lines(...)`             | [create_hvdc_lines](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_hvdc_lines.html#pypowsybl.network.Network.create_hvdc_lines) |
# | Shunt Compensator            | `Network.create_shunt_compensators(...)`     | [create_shunt_compensators](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_shunt_compensators.html#pypowsybl.network.Network.create_shunt_compensators) |
# | Static Var Compensator       | `Network.create_static_var_compensators(...)`| [create_static_var_compensators](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_static_var_compensators.html#pypowsybl.network.Network.create_static_var_compensators) |
# | Substation                   | `Network.create_substations(...)`            | [create_substations](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_substations.html#pypowsybl.network.Network.create_substations) |
# | Voltage Level                | `Network.create_voltage_levels(...)`         | [create_voltage_levels](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_voltage_levels.html#pypowsybl.network.Network.create_voltage_levels) |
# | Busbar Section               | `Network.create_busbar_sections(...)`        | [create_busbar_sections](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_busbar_sections.html#pypowsybl.network.Network.create_busbar_sections) |
# | Switch                       | `Network.create_switches(...)`               | [create_switches](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_switches.html#pypowsybl.network.Network.create_switches) |
# | Operational Limits           | `Network.create_operational_limits(...)`     | [create_operational_limits](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_operational_limits.html#pypowsybl.network.Network.create_operational_limits) |
# | Ratio Tap Changer            | `Network.create_ratio_tap_changers(...)`     | [create_ratio_tap_changers](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_ratio_tap_changers.html#pypowsybl.network.Network.create_ratio_tap_changers) |
# | Phase Tap Changer            | `Network.create_phase_tap_changers(...)`     | [create_phase_tap_changers](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_phase_tap_changers.html#pypowsybl.network.Network.create_phase_tap_changers) |
# | Min/Max Reactive Limits      | `Network.create_minmax_reactive_limits(...)` | [create_minmax_reactive_limits](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_minmax_reactive_limits.html#pypowsybl.network.Network.create_minmax_reactive_limits) |
# | Curve Reactive Limits        | `Network.create_curve_reactive_limits(...)`  | [create_curve_reactive_limits](https://powsybl.readthedocs.io/projects/pypowsybl/en/stable/reference/api/pypowsybl.network.Network.create_curve_reactive_limits.html#pypowsybl.network.Network.create_curve_reactive_limits) |
