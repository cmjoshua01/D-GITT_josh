# %% [markdown]
# # Shunt blocks
#
# In PowSyBl, the shunt compensators consist of discrete blocks which can be defined either with a linear model or with a non-linear (discrete) model. This particularity requires a more detailed initialization of this element, which is explained in this notebook.
#
# ## Linear shunts
#
# The blocks of linear shunts are identical between each other, meaning that we only need the size of one of them and the total amount in order to model completely the element. To create this shunt we need a linear_shunt_df, and then define the element as follows:

# %%
import pypowsybl as pp
import pandas as pd
import numpy as np

grid = pp.network.create_empty()
grid.create_substations(id=['ss1'])
grid.create_voltage_levels(id=['vl1'], substation_id=['ss1'], topology_kind=['BUS_BREAKER'], nominal_v=[10] )
grid.create_buses(id=['b1'], voltage_level_id=['vl1'])


linear_model_df = pd.DataFrame.from_records(
    index='id',
    columns=['id', 'g_per_section', 'b_per_section', 'max_section_count'],
    data=[('linear_shunt', 0.1, -0.01, 5)])

linear_shunt_df = pd.DataFrame.from_records(
    index='id',
    columns=['id', 'name', 'model_type', 'section_count', 'target_v',
             'target_deadband', 'voltage_level_id', 'bus_id'],
    data=[('linear_shunt', 'LSH', 'LINEAR', 5, 10, 2, 'vl1', 'b1')])

grid.create_shunt_compensators(linear_shunt_df, linear_model_df)

# %%
grid.get_shunt_compensators(all_attributes=True)
# Out:
#              name    g     b model_type  max_section_count  section_count  \
# id
# linear_shunt  LSH  0.5 -0.05     LINEAR                  5              5
#
#               solved_section_count  voltage_regulation_on  target_v  \
# id
# linear_shunt                   NaN                  False      10.0
#
#               target_deadband regulating_bus_id   p   q   i voltage_level_id  \
# id
# linear_shunt              2.0             vl1_0 NaN NaN NaN              vl1
#
#              bus_id bus_breaker_bus_id  node  connected  fictitious
# id
# linear_shunt  vl1_0                 b1    -1       True       False

# %% [raw]
# Basically, we are defining a shunt element which has a total of 5 blocks, each of them with a g=0.1 and b=-0.01. We can update the section count to change the number of connected blocks:

# %%
grid.update_shunt_compensators(id='linear_shunt', section_count=3)
grid.get_shunt_compensators(all_attributes=True)
# Out:
#              name    g     b model_type  max_section_count  section_count  \
# id
# linear_shunt  LSH  0.3 -0.03     LINEAR                  5              3
#
#               solved_section_count  voltage_regulation_on  target_v  \
# id
# linear_shunt                   NaN                  False      10.0
#
#               target_deadband regulating_bus_id   p   q   i voltage_level_id  \
# id
# linear_shunt              2.0             vl1_0 NaN NaN NaN              vl1
#
#              bus_id bus_breaker_bus_id  node  connected  fictitious
# id
# linear_shunt  vl1_0                 b1    -1       True       False

# %% [markdown]
# But if we try to set a section_count higher than the total amount, we will get an error saying that the section count is outside the limit.

# %%
grid.update_shunt_compensators(id='linear_shunt', section_count=6)
grid.get_shunt_compensators(all_attributes=True)
# Out:
# ---------------------------------------------------------------------------
# PyPowsyblError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 grid.update_shunt_compensators(id='linear_shunt', section_count=6)
#       2 grid.get_shunt_compensators(all_attributes=True)
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/network/impl/network.py:3616, in Network.update_shunt_compensators(self, df, **kwargs)
#    3586 def update_shunt_compensators(self, df: Optional[DataFrame] = None, **kwargs: ArrayLike) -> None:
#    3587     """
#    3588     Update shunt compensators with data provided as a :class:`~pandas.DataFrame` or as named arguments.
#    3589
#    (...)   3614             network.update_shunt_compensators(id=['IND-1', 'CAP-1'], section_count=[1, 0])
#    3615     """
# -> 3616     return self._update_elements(ElementType.SHUNT_COMPENSATOR, df, **kwargs)
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/network/impl/network.py:2900, in Network._update_elements(self, element_type, df, **kwargs)
#    2898 df = _adapt_df_or_kwargs(metadata, df, **kwargs)
#    2899 c_df = _create_c_dataframe(df, metadata)
# -> 2900 _pp.update_network_elements_with_series(self._handle, c_df, element_type, self._per_unit,
#    2901                                         self._nominal_apparent_power)
#
# PyPowsyblError: Shunt compensator 'linear_shunt': the current number (6) of section should be lesser than the maximum number of section (5)

# %% [markdown]
# ## Non-linear shunts
#
# For these types of shunts, the initialitation now requires the input of the individual blocks instead

# %%
nonlinear_model_df = pd.DataFrame.from_records(
    index='id',
    columns=['id', 'g', 'b'],
    data=[('NLSH', 0.1, -0.01),
          ('NLSH', 0.3, -0.03),
          ('NLSH', 0.5, -0.05)])

nonlinear_shunt_df = pd.DataFrame.from_records(
    index='id',
    columns=['id', 'name', 'model_type', 'section_count', 'target_v',
             'target_deadband', 'voltage_level_id', 'bus_id'],
    data=[('NLSH', 'NLSH', 'NON_LINEAR', 3, 10, 2, 'vl1', 'b1')])

grid.create_shunt_compensators(nonlinear_shunt_df, nonlinear_model_df)
grid.get_shunt_compensators(all_attributes=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 29
#      15 shunt_df = pd.DataFrame.from_records(
#      16                     index='id',
#      17                     columns=['id', 'name', 'model_type', 'section_count', 'target_v',
#      18                              'target_deadband', 'voltage_level_id', 'node'],
#      19                     data=[('SHUNT1', '', 'NON_LINEAR', 1, 400, 2, 'S1VL2', 2),
#      20                           ('SHUNT2', '', 'NON_LINEAR', 1, 400, 2, 'S1VL2', 10)])
#      21 model_df = pd.DataFrame.from_records(
#      22                     index='id',
#      23                     columns=['id', 'g', 'b'],
#    (...)     26                           ('SHUNT2', 5, 6),
#      27                           ('SHUNT2', 7, 8)])
# ---> 29 grid.create_shunt_compensators(shunt_df, model_df)
#      30 grid.get_shunt_compensators(all_attributes=True)
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/network/impl/network.py:4828, in Network.create_shunt_compensators(self, shunt_df, linear_model_df, non_linear_model_df)
#    4826     non_linear_model_df = pd.DataFrame()
#    4827 dfs: List[Optional[DataFrame]] = [shunt_df, linear_model_df, non_linear_model_df]
# -> 4828 return self._create_elements(ElementType.SHUNT_COMPENSATOR, dfs)
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/network/impl/network.py:4087, in Network._create_elements(self, element_type, dfs, **kwargs)
#    4084 def _create_elements(self, element_type: ElementType, dfs: List[Optional[DataFrame]],
#    4085                      **kwargs: ArrayLike) -> None:
#    4086     metadata = _pp.get_network_elements_creation_dataframes_metadata(element_type)
# -> 4087     c_dfs = _get_c_dataframes(dfs, metadata, **kwargs)
#    4088     _pp.create_element(self._handle, c_dfs, element_type)
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/utils/impl/dataframes.py:190, in _get_c_dataframes(dfs, metadata, **kwargs)
#     188         c_dfs.append(None)
#     189     else:
# --> 190         c_dfs.append(_create_c_dataframe(df, metadata[i]))
#     191 return c_dfs
#
# File ~/Github/D-GITT/.Python/lib/python3.12/site-packages/pypowsybl/utils/impl/dataframes.py:101, in _create_c_dataframe(df, series_metadata)
#      99 for series_name in df.columns.values:
#     100     if series_name not in metadata_by_name:
# --> 101         raise ValueError(f'No column named {series_name}')
#     102     series = df[series_name]
#     103     series_type = metadata_by_name[series_name].type
#
# ValueError: No column named g
