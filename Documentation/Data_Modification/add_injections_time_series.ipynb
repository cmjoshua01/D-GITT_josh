# %% [markdown]
# # Adding time-series injections
#
# WIP

# %%
import pypowsybl as pp
import pandas as pd
from pathlib import Path

grid = pp.network.load(file='future_snapshot.xiidm.bz2')
print('Grid model loaded')

# %% [markdown]
# If we want to get a time series of a parameter of an element, we will need to create a loop that opens all the files that we want to evaluate:

# %%
# Assuming we already have a list of files from the path, and we want to store all the Resistance values of all the lines

list_files = ['initial_snapshot.xiidm.bz2', 'future_snapshot.xiidm.bz2']
rdata = {}
for i, file in enumerate(list_files):
    grid = pp.network.load(file)
    r_values = grid.get_lines(attributes=['r'])['r'] 
    timestep = Path(file).stem # Here we use the snapshot name to be the name of the column. You could choose some other name for the columns of the time series.
    rdata[f'Snap{i}: {timestep}'] = r_values

r_timeseries = pd.DataFrame(rdata)
r_timeseries
# Out:
#                Snap0: initial_snapshot.xiidm  Snap1: future_snapshot.xiidm
# id
# .CTLHL31.CTLO                       1.149352                      1.149352
# .CTLHL32.CTLO                       1.149352                      1.149352
# .CTLOL31FINS                        2.127000                      2.127000
# .CTLOL31ZLIEB                       3.870000                      3.870000
# .G.ROL51HOSPI                       1.599000                      1.599000
# ...                                      ...                           ...
# ZNAUSL31ZPRA5                       6.660255                      6.660255
# ZPRRFL32ZPRR5                       0.050000                      0.050000
# ZQUINL61ZSSCR                       0.350000                      0.350000
# ZS.SEL31ZVLET                       0.100000                      0.100000
# ZTRINL31ZP.F5                       1.831000                      1.831000
#
# [7808 rows x 2 columns]
